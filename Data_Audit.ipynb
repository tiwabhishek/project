# %%
import pandas as pd
import numpy as np
df=pd.read_csv('weatherAUS.csv')

# %%
Data_audit = pd.DataFrame()
print(Data_audit)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Data_audit['Name Of the Column'] = df.columns.tolist()

# %%
Variable_type=[]
for n in df.columns.tolist():
    if n == 'RainTomorrow':
        Variable_type.append('Target')
    else:
        Variable_type.append('Feature')


print(Variable_type)
Data_audit["Variable's type"] = Variable_type
# Out:
# ['Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Feature', 'Target']

# %%
Data_audit["Percentage of missing values"]=((df.isnull().sum() / len(df)) * 100).values.round(1)

# %%
Categorical_Quantitative =[]
for n in df.dtypes.tolist():
    if n == object:
        Categorical_Quantitative.append('Categorical')
    else:
        Categorical_Quantitative.append('Quantitative')


print(Categorical_Quantitative)
Categorical_Quantitative[0]="Categorical"
Data_audit["Categorical/Quantitative"] = Categorical_Quantitative
# Out:
# ['Categorical', 'Categorical', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Categorical', 'Quantitative', 'Categorical', 'Categorical', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Quantitative', 'Categorical', 'Categorical']

# %%
Data_audit
# Out:
#    Name Of the Column Variable's type  Percentage of missing values  \
# 0                Date         Feature                           0.0
# 1            Location         Feature                           0.0
# 2             MinTemp         Feature                           1.0
# 3             MaxTemp         Feature                           0.9
# 4            Rainfall         Feature                           2.2
# 5         Evaporation         Feature                          43.2
# 6            Sunshine         Feature                          48.0
# 7         WindGustDir         Feature                           7.1
# 8       WindGustSpeed         Feature                           7.1
# 9          WindDir9am         Feature                           7.3
# 10         WindDir3pm         Feature                           2.9
# 11       WindSpeed9am         Feature                           1.2
# 12       WindSpeed3pm         Feature                           2.1
# 13        Humidity9am         Feature                           1.8
# 14        Humidity3pm         Feature                           3.1
# 15        Pressure9am         Feature                          10.4
# 16        Pressure3pm         Feature                          10.3
# 17           Cloud9am         Feature                          38.4
# 18           Cloud3pm         Feature                          40.8
# 19            Temp9am         Feature                           1.2
# 20            Temp3pm         Feature                           2.5
# 21          RainToday         Feature                           2.2
# 22       RainTomorrow          Target                           2.2
#
#    Categorical/Quantitative
# 0               Categorical
# 1               Categorical
# 2              Quantitative
# 3              Quantitative
# 4              Quantitative
# 5              Quantitative
# 6              Quantitative
# 7               Categorical
# 8              Quantitative
# 9               Categorical
# 10              Categorical
# 11             Quantitative
# 12             Quantitative
# 13             Quantitative
# 14             Quantitative
# 15             Quantitative
# 16             Quantitative
# 17             Quantitative
# 18             Quantitative
# 19             Quantitative
# 20             Quantitative
# 21              Categorical
# 22              Categorical

# %%
Description_list=["The date of observation","The common name of the location of the weather station","The minimum temperature in degrees celsius","The maximum temperature in degrees celsius","The amount of rainfall recorded for the day in mm","The so-called Class A pan evaporation (mm) in the 24 hours to 9am","The number of hours of bright sunshine in the day","The direction of the strongest wind gust in the 24 hours to midnight","The speed (km/h) of the strongest wind gust in the 24 hours to midnight","Direction of the wind at 9am","Direction of the wind at 3pm","Wind speed (km/hr) averaged over 10 minutes prior to 9am","Wind speed (km/hr) averaged over 10 minutes prior to 3pm","Humidity (percent) at 9am","Humidity (percent) at 3pm","Atmospheric pressure (hpa) reduced to mean sea level at 9am","Atmospheric pressure (hpa) reduced to mean sea level at 3pm","Fraction of sky obscured by cloud at 9am. This is measured in 'oktas', which are a unit of eigths. It records how many eigths of the sky are obscured by cloud. A 0 measure indicates completely clear sky whilst an 8 indicates that it is completely overcast.","Fraction of sky obscured by cloud (in 'oktas': eighths) at 3pm. See Cload9am for a description of the values","Temperature (degrees C) at 9am","Temperature (degrees C) at 3pm","yes if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise No","The amount of next day rain in mm. Used to create response variable RainTomorrow. A kind of measure of the 'risk'."]
Data_audit["Description"]=Description_list

# %%
predctable_list=[]
for i in Data_audit["Variable's type"]:
    if i =="Feature":
        predctable_list.append('it was known before prediction made')
    else:
        predctable_list.append('it was not known before prediction made')

Data_audit["Is the variable available before prediction"]=predctable_list

# %%
Data_audit
# Out:
#    Name Of the Column Variable's type  Percentage of missing values  \
# 0                Date         Feature                           0.0
# 1            Location         Feature                           0.0
# 2             MinTemp         Feature                           1.0
# 3             MaxTemp         Feature                           0.9
# 4            Rainfall         Feature                           2.2
# 5         Evaporation         Feature                          43.2
# 6            Sunshine         Feature                          48.0
# 7         WindGustDir         Feature                           7.1
# 8       WindGustSpeed         Feature                           7.1
# 9          WindDir9am         Feature                           7.3
# 10         WindDir3pm         Feature                           2.9
# 11       WindSpeed9am         Feature                           1.2
# 12       WindSpeed3pm         Feature                           2.1
# 13        Humidity9am         Feature                           1.8
# 14        Humidity3pm         Feature                           3.1
# 15        Pressure9am         Feature                          10.4
# 16        Pressure3pm         Feature                          10.3
# 17           Cloud9am         Feature                          38.4
# 18           Cloud3pm         Feature                          40.8
# 19            Temp9am         Feature                           1.2
# 20            Temp3pm         Feature                           2.5
# 21          RainToday         Feature                           2.2
# 22       RainTomorrow          Target                           2.2
#
#    Categorical/Quantitative  \
# 0               Categorical
# 1               Categorical
# 2              Quantitative
# 3              Quantitative
# 4              Quantitative
# 5              Quantitative
# 6              Quantitative
# 7               Categorical
# 8              Quantitative
# 9               Categorical
# 10              Categorical
# 11             Quantitative
# 12             Quantitative
# 13             Quantitative
# 14             Quantitative
# 15             Quantitative
# 16             Quantitative
# 17             Quantitative
# 18             Quantitative
# 19             Quantitative
# 20             Quantitative
# 21              Categorical
# 22              Categorical
#
#                                           Description  \
# 0                             The date of observation
# 1   The common name of the location of the weather...
# 2          The minimum temperature in degrees celsius
# 3          The maximum temperature in degrees celsius
# 4   The amount of rainfall recorded for the day in mm
# 5   The so-called Class A pan evaporation (mm) in ...
# 6   The number of hours of bright sunshine in the day
# 7   The direction of the strongest wind gust in th...
# 8   The speed (km/h) of the strongest wind gust in...
# 9                        Direction of the wind at 9am
# 10                       Direction of the wind at 3pm
# 11  Wind speed (km/hr) averaged over 10 minutes pr...
# 12  Wind speed (km/hr) averaged over 10 minutes pr...
# 13                          Humidity (percent) at 9am
# 14                          Humidity (percent) at 3pm
# 15  Atmospheric pressure (hpa) reduced to mean sea...
# 16  Atmospheric pressure (hpa) reduced to mean sea...
# 17  Fraction of sky obscured by cloud at 9am. This...
# 18  Fraction of sky obscured by cloud (in 'oktas':...
# 19                     Temperature (degrees C) at 9am
# 20                     Temperature (degrees C) at 3pm
# 21  yes if precipitation (mm) in the 24 hours to 9...
# 22  The amount of next day rain in mm. Used to cre...
#
#    Is the variable available before prediction  \
# 0          it was known before prediction made
# 1          it was known before prediction made
# 2          it was known before prediction made
# 3          it was known before prediction made
# 4          it was known before prediction made
# 5          it was known before prediction made
# 6          it was known before prediction made
# 7          it was known before prediction made
# 8          it was known before prediction made
# 9          it was known before prediction made
# 10         it was known before prediction made
# 11         it was known before prediction made
# 12         it was known before prediction made
# 13         it was known before prediction made
# 14         it was known before prediction made
# 15         it was known before prediction made
# 16         it was known before prediction made
# 17         it was known before prediction made
# 18         it was known before prediction made
# 19         it was known before prediction made
# 20         it was known before prediction made
# 21         it was known before prediction made
# 22     it was not known before prediction made
#
#                                          Distribution Variable's d-type  \
# 0                it represent the date of observation    datetime64[ns]
# 1   [Canberra, Sydney, Darwin, Melbourne, Brisbane...            object
# 2   count    143975.0
# mean         12.2
# std       ...           float64
# 3   count    144199.0
# mean         23.2
# std       ...           float64
# 4   count    142199.0
# mean          2.4
# std       ...           float64
# 5   count    82670.0
# mean         5.5
# std         ...           float64
# 6   count    75625.0
# mean         7.6
# std         ...           float64
# 7            [W, SE, N, SSE, E, S, WSW, SW, SSW, WNW]            object
# 8   count    135197.0
# mean         40.0
# std       ...           float64
# 9             [N, SE, E, SSE, NW, S, W, SW, NNE, NNW]            object
# 10          [SE, W, S, WSW, SSE, SW, N, WNW, NW, ESE]            object
# 11  count    143693.0
# mean         14.0
# std       ...           float64
# 12  count    142398.0
# mean         18.7
# std       ...           float64
# 13  count    142806.0
# mean         68.9
# std       ...           float64
# 14  count    140953.0
# mean         51.5
# std       ...           float64
# 15  count    130395.0
# mean       1017.6
# std       ...           float64
# 16  count    130432.0
# mean       1015.3
# std       ...           float64
# 17  count    89572.0
# mean         4.4
# std         ...           float64
# 18  count    86102.0
# mean         4.5
# std         ...           float64
# 19  count    143693.0
# mean         17.0
# std       ...           float64
# 20  count    141851.0
# mean         21.7
# std       ...           float64
# 21                                     [No, Yes, nan]            object
# 22                                     [No, Yes, nan]            object
#
#     Number of lines in the table : ?
# 0                             145460
# 1                             145460
# 2                             143975
# 3                             144199
# 4                             142199
# 5                              82670
# 6                              75625
# 7                             135134
# 8                             135197
# 9                             134894
# 10                            141232
# 11                            143693
# 12                            142398
# 13                            142806
# 14                            140953
# 15                            130395
# 16                            130432
# 17                             89572
# 18                             86102
# 19                            143693
# 20                            141851
# 21                            142199
# 22                            142193

# %%
unique_values=[]
for n in df.columns:
    if df[n].dtype==object:
        if df[n].nunique()>10:
            unique_values.append(df[n].value_counts().index[:10].tolist())
        else:
            unique_values.append(df[n].unique())
    else:
        unique_values.append(df[n].describe().round(1))
unique_values[0]="it represent the date of observation"   
print(unique_values)
# Out:
# ['it represent the date of observation', ['Canberra', 'Sydney', 'Darwin', 'Melbourne', 'Brisbane', 'Adelaide', 'Perth', 'Hobart', 'Albany', 'MountGambier'], count    143975.0
# mean         12.2
# std           6.4
# min          -8.5
# 25%           7.6
# 50%          12.0
# 75%          16.9
# max          33.9
# Name: MinTemp, dtype: float64, count    144199.0
# mean         23.2
# std           7.1
# min          -4.8
# 25%          17.9
# 50%          22.6
# 75%          28.2
# max          48.1
# Name: MaxTemp, dtype: float64, count    142199.0
# mean          2.4
# std           8.5
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.8
# max         371.0
# Name: Rainfall, dtype: float64, count    82670.0
# mean         5.5
# std          4.2
# min          0.0
# 25%          2.6
# 50%          4.8
# 75%          7.4
# max        145.0
# Name: Evaporation, dtype: float64, count    75625.0
# mean         7.6
# std          3.8
# min          0.0
# 25%          4.8
# 50%          8.4
# 75%         10.6
# max         14.5
# Name: Sunshine, dtype: float64, ['W', 'SE', 'N', 'SSE', 'E', 'S', 'WSW', 'SW', 'SSW', 'WNW'], count    135197.0
# mean         40.0
# std          13.6
# min           6.0
# 25%          31.0
# 50%          39.0
# 75%          48.0
# max         135.0
# Name: WindGustSpeed, dtype: float64, ['N', 'SE', 'E', 'SSE', 'NW', 'S', 'W', 'SW', 'NNE', 'NNW'], ['SE', 'W', 'S', 'WSW', 'SSE', 'SW', 'N', 'WNW', 'NW', 'ESE'], count    143693.0
# mean         14.0
# std           8.9
# min           0.0
# 25%           7.0
# 50%          13.0
# 75%          19.0
# max         130.0
# Name: WindSpeed9am, dtype: float64, count    142398.0
# mean         18.7
# std           8.8
# min           0.0
# 25%          13.0
# 50%          19.0
# 75%          24.0
# max          87.0
# Name: WindSpeed3pm, dtype: float64, count    142806.0
# mean         68.9
# std          19.0
# min           0.0
# 25%          57.0
# 50%          70.0
# 75%          83.0
# max         100.0
# Name: Humidity9am, dtype: float64, count    140953.0
# mean         51.5
# std          20.8
# min           0.0
# 25%          37.0
# 50%          52.0
# 75%          66.0
# max         100.0
# Name: Humidity3pm, dtype: float64, count    130395.0
# mean       1017.6
# std           7.1
# min         980.5
# 25%        1012.9
# 50%        1017.6
# 75%        1022.4
# max        1041.0
# Name: Pressure9am, dtype: float64, count    130432.0
# mean       1015.3
# std           7.0
# min         977.1
# 25%        1010.4
# 50%        1015.2
# 75%        1020.0
# max        1039.6
# Name: Pressure3pm, dtype: float64, count    89572.0
# mean         4.4
# std          2.9
# min          0.0
# 25%          1.0
# 50%          5.0
# 75%          7.0
# max          9.0
# Name: Cloud9am, dtype: float64, count    86102.0
# mean         4.5
# std          2.7
# min          0.0
# 25%          2.0
# 50%          5.0
# 75%          7.0
# max          9.0
# Name: Cloud3pm, dtype: float64, count    143693.0
# mean         17.0
# std           6.5
# min          -7.2
# 25%          12.3
# 50%          16.7
# 75%          21.6
# max          40.2
# Name: Temp9am, dtype: float64, count    141851.0
# mean         21.7
# std           6.9
# min          -5.4
# 25%          16.6
# 50%          21.1
# 75%          26.4
# max          46.7
# Name: Temp3pm, dtype: float64, array(['No', 'Yes', nan], dtype=object), array(['No', 'Yes', nan], dtype=object)]

# %% [markdown]
# I had to run this cell before changing the dtype of the date column because this code does not work if the date column is in datetime64 dtype.

# %%
Data_audit["Distribution"]=unique_values

# %%
Data_audit
# Out:
#    Name Of the Column Variable's type  Percentage of missing values  \
# 0                Date         Feature                           0.0
# 1            Location         Feature                           0.0
# 2             MinTemp         Feature                           1.0
# 3             MaxTemp         Feature                           0.9
# 4            Rainfall         Feature                           2.2
# 5         Evaporation         Feature                          43.2
# 6            Sunshine         Feature                          48.0
# 7         WindGustDir         Feature                           7.1
# 8       WindGustSpeed         Feature                           7.1
# 9          WindDir9am         Feature                           7.3
# 10         WindDir3pm         Feature                           2.9
# 11       WindSpeed9am         Feature                           1.2
# 12       WindSpeed3pm         Feature                           2.1
# 13        Humidity9am         Feature                           1.8
# 14        Humidity3pm         Feature                           3.1
# 15        Pressure9am         Feature                          10.4
# 16        Pressure3pm         Feature                          10.3
# 17           Cloud9am         Feature                          38.4
# 18           Cloud3pm         Feature                          40.8
# 19            Temp9am         Feature                           1.2
# 20            Temp3pm         Feature                           2.5
# 21          RainToday         Feature                           2.2
# 22       RainTomorrow          Target                           2.2
#
#    Categorical/Quantitative  \
# 0               Categorical
# 1               Categorical
# 2              Quantitative
# 3              Quantitative
# 4              Quantitative
# 5              Quantitative
# 6              Quantitative
# 7               Categorical
# 8              Quantitative
# 9               Categorical
# 10              Categorical
# 11             Quantitative
# 12             Quantitative
# 13             Quantitative
# 14             Quantitative
# 15             Quantitative
# 16             Quantitative
# 17             Quantitative
# 18             Quantitative
# 19             Quantitative
# 20             Quantitative
# 21              Categorical
# 22              Categorical
#
#                                           Description  \
# 0                             The date of observation
# 1   The common name of the location of the weather...
# 2          The minimum temperature in degrees celsius
# 3          The maximum temperature in degrees celsius
# 4   The amount of rainfall recorded for the day in mm
# 5   The so-called Class A pan evaporation (mm) in ...
# 6   The number of hours of bright sunshine in the day
# 7   The direction of the strongest wind gust in th...
# 8   The speed (km/h) of the strongest wind gust in...
# 9                        Direction of the wind at 9am
# 10                       Direction of the wind at 3pm
# 11  Wind speed (km/hr) averaged over 10 minutes pr...
# 12  Wind speed (km/hr) averaged over 10 minutes pr...
# 13                          Humidity (percent) at 9am
# 14                          Humidity (percent) at 3pm
# 15  Atmospheric pressure (hpa) reduced to mean sea...
# 16  Atmospheric pressure (hpa) reduced to mean sea...
# 17  Fraction of sky obscured by cloud at 9am. This...
# 18  Fraction of sky obscured by cloud (in 'oktas':...
# 19                     Temperature (degrees C) at 9am
# 20                     Temperature (degrees C) at 3pm
# 21  yes if precipitation (mm) in the 24 hours to 9...
# 22  The amount of next day rain in mm. Used to cre...
#
#    Is the variable available before prediction  \
# 0           it was kwon before prediction made
# 1           it was kwon before prediction made
# 2           it was kwon before prediction made
# 3           it was kwon before prediction made
# 4           it was kwon before prediction made
# 5           it was kwon before prediction made
# 6           it was kwon before prediction made
# 7           it was kwon before prediction made
# 8           it was kwon before prediction made
# 9           it was kwon before prediction made
# 10          it was kwon before prediction made
# 11          it was kwon before prediction made
# 12          it was kwon before prediction made
# 13          it was kwon before prediction made
# 14          it was kwon before prediction made
# 15          it was kwon before prediction made
# 16          it was kwon before prediction made
# 17          it was kwon before prediction made
# 18          it was kwon before prediction made
# 19          it was kwon before prediction made
# 20          it was kwon before prediction made
# 21          it was kwon before prediction made
# 22      it was not kwon before prediction made
#
#                                          Distribution Variable's d-type
# 0                it represent the date of observation    datetime64[ns]
# 1   [Canberra, Sydney, Darwin, Melbourne, Brisbane...            object
# 2   count    143975.0
# mean         12.2
# std       ...           float64
# 3   count    144199.0
# mean         23.2
# std       ...           float64
# 4   count    142199.0
# mean          2.4
# std       ...           float64
# 5   count    82670.0
# mean         5.5
# std         ...           float64
# 6   count    75625.0
# mean         7.6
# std         ...           float64
# 7            [W, SE, N, SSE, E, S, WSW, SW, SSW, WNW]            object
# 8   count    135197.0
# mean         40.0
# std       ...           float64
# 9             [N, SE, E, SSE, NW, S, W, SW, NNE, NNW]            object
# 10          [SE, W, S, WSW, SSE, SW, N, WNW, NW, ESE]            object
# 11  count    143693.0
# mean         14.0
# std       ...           float64
# 12  count    142398.0
# mean         18.7
# std       ...           float64
# 13  count    142806.0
# mean         68.9
# std       ...           float64
# 14  count    140953.0
# mean         51.5
# std       ...           float64
# 15  count    130395.0
# mean       1017.6
# std       ...           float64
# 16  count    130432.0
# mean       1015.3
# std       ...           float64
# 17  count    89572.0
# mean         4.4
# std         ...           float64
# 18  count    86102.0
# mean         4.5
# std         ...           float64
# 19  count    143693.0
# mean         17.0
# std       ...           float64
# 20  count    141851.0
# mean         21.7
# std       ...           float64
# 21                                     [No, Yes, nan]            object
# 22                                     [No, Yes, nan]            object

# %%
df['Date'] = pd.to_datetime(df['Date'])

Data_audit["Variable's d-type"] = df.dtypes.tolist()

# %%
Data_audit["Number of lines in the table : ?"]=df.count().tolist()

# %%
Data_audit
# Out:
#    Name Of the Column Variable's type  Percentage of missing values  \
# 0                Date         Feature                           0.0
# 1            Location         Feature                           0.0
# 2             MinTemp         Feature                           1.0
# 3             MaxTemp         Feature                           0.9
# 4            Rainfall         Feature                           2.2
# 5         Evaporation         Feature                          43.2
# 6            Sunshine         Feature                          48.0
# 7         WindGustDir         Feature                           7.1
# 8       WindGustSpeed         Feature                           7.1
# 9          WindDir9am         Feature                           7.3
# 10         WindDir3pm         Feature                           2.9
# 11       WindSpeed9am         Feature                           1.2
# 12       WindSpeed3pm         Feature                           2.1
# 13        Humidity9am         Feature                           1.8
# 14        Humidity3pm         Feature                           3.1
# 15        Pressure9am         Feature                          10.4
# 16        Pressure3pm         Feature                          10.3
# 17           Cloud9am         Feature                          38.4
# 18           Cloud3pm         Feature                          40.8
# 19            Temp9am         Feature                           1.2
# 20            Temp3pm         Feature                           2.5
# 21          RainToday         Feature                           2.2
# 22       RainTomorrow          Target                           2.2
#
#    Categorical/Quantitative  \
# 0               Categorical
# 1               Categorical
# 2              Quantitative
# 3              Quantitative
# 4              Quantitative
# 5              Quantitative
# 6              Quantitative
# 7               Categorical
# 8              Quantitative
# 9               Categorical
# 10              Categorical
# 11             Quantitative
# 12             Quantitative
# 13             Quantitative
# 14             Quantitative
# 15             Quantitative
# 16             Quantitative
# 17             Quantitative
# 18             Quantitative
# 19             Quantitative
# 20             Quantitative
# 21              Categorical
# 22              Categorical
#
#                                           Description  \
# 0                             The date of observation
# 1   The common name of the location of the weather...
# 2          The minimum temperature in degrees celsius
# 3          The maximum temperature in degrees celsius
# 4   The amount of rainfall recorded for the day in mm
# 5   The so-called Class A pan evaporation (mm) in ...
# 6   The number of hours of bright sunshine in the day
# 7   The direction of the strongest wind gust in th...
# 8   The speed (km/h) of the strongest wind gust in...
# 9                        Direction of the wind at 9am
# 10                       Direction of the wind at 3pm
# 11  Wind speed (km/hr) averaged over 10 minutes pr...
# 12  Wind speed (km/hr) averaged over 10 minutes pr...
# 13                          Humidity (percent) at 9am
# 14                          Humidity (percent) at 3pm
# 15  Atmospheric pressure (hpa) reduced to mean sea...
# 16  Atmospheric pressure (hpa) reduced to mean sea...
# 17  Fraction of sky obscured by cloud at 9am. This...
# 18  Fraction of sky obscured by cloud (in 'oktas':...
# 19                     Temperature (degrees C) at 9am
# 20                     Temperature (degrees C) at 3pm
# 21  yes if precipitation (mm) in the 24 hours to 9...
# 22  The amount of next day rain in mm. Used to cre...
#
#    Is the variable available before prediction  \
# 0           it was kwon before prediction made
# 1           it was kwon before prediction made
# 2           it was kwon before prediction made
# 3           it was kwon before prediction made
# 4           it was kwon before prediction made
# 5           it was kwon before prediction made
# 6           it was kwon before prediction made
# 7           it was kwon before prediction made
# 8           it was kwon before prediction made
# 9           it was kwon before prediction made
# 10          it was kwon before prediction made
# 11          it was kwon before prediction made
# 12          it was kwon before prediction made
# 13          it was kwon before prediction made
# 14          it was kwon before prediction made
# 15          it was kwon before prediction made
# 16          it was kwon before prediction made
# 17          it was kwon before prediction made
# 18          it was kwon before prediction made
# 19          it was kwon before prediction made
# 20          it was kwon before prediction made
# 21          it was kwon before prediction made
# 22      it was not kwon before prediction made
#
#                                          Distribution Variable's d-type  \
# 0                it represent the date of observation    datetime64[ns]
# 1   [Canberra, Sydney, Darwin, Melbourne, Brisbane...            object
# 2   count    143975.0
# mean         12.2
# std       ...           float64
# 3   count    144199.0
# mean         23.2
# std       ...           float64
# 4   count    142199.0
# mean          2.4
# std       ...           float64
# 5   count    82670.0
# mean         5.5
# std         ...           float64
# 6   count    75625.0
# mean         7.6
# std         ...           float64
# 7            [W, SE, N, SSE, E, S, WSW, SW, SSW, WNW]            object
# 8   count    135197.0
# mean         40.0
# std       ...           float64
# 9             [N, SE, E, SSE, NW, S, W, SW, NNE, NNW]            object
# 10          [SE, W, S, WSW, SSE, SW, N, WNW, NW, ESE]            object
# 11  count    143693.0
# mean         14.0
# std       ...           float64
# 12  count    142398.0
# mean         18.7
# std       ...           float64
# 13  count    142806.0
# mean         68.9
# std       ...           float64
# 14  count    140953.0
# mean         51.5
# std       ...           float64
# 15  count    130395.0
# mean       1017.6
# std       ...           float64
# 16  count    130432.0
# mean       1015.3
# std       ...           float64
# 17  count    89572.0
# mean         4.4
# std         ...           float64
# 18  count    86102.0
# mean         4.5
# std         ...           float64
# 19  count    143693.0
# mean         17.0
# std       ...           float64
# 20  count    141851.0
# mean         21.7
# std       ...           float64
# 21                                     [No, Yes, nan]            object
# 22                                     [No, Yes, nan]            object
#
#     Number of lines in the table : ?
# 0                             145460
# 1                             145460
# 2                             143975
# 3                             144199
# 4                             142199
# 5                              82670
# 6                              75625
# 7                             135134
# 8                             135197
# 9                             134894
# 10                            141232
# 11                            143693
# 12                            142398
# 13                            142806
# 14                            140953
# 15                            130395
# 16                            130432
# 17                             89572
# 18                             86102
# 19                            143693
# 20                            141851
# 21                            142199
# 22                            142193
